# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <h1 style="color:green; margin-bottom:20px">Комментарий ревьювера</h1>
#
# Алекс, привет!
#
# 🤚 Меня зовут Волкова Оля, я буду проверять твой проект. Если не против, я буду обращаться к тебе на _ТЫ_ . Если
#     предпочтительнее общение на _ВЫ_ , то обязательно напиши мне об этом в комментариях.
#
#
# ✏️ В этой тетрадке далее мои комментарии будут выделены по цветам:
#
#
# <div class="alert alert-block alert-success">
# <b>✔️ Комментарий ревьюера:</b> Зеленный блок указывает на твои удачные решения и сильные стороны работы
# </div>
#
#
#
#
# <div class="alert alert-block alert-warning">
# <b> ⚠️ Комментарий ревьюера:</b> Желтый блок указывает на то, что задание решено корректно, но какие-то вещи можно улучшить для большей эффективности работы, чистоты кода, поддержки и пр.
# </div>
#
#
# <div class="alert alert-block alert-danger">
# <b> ❌ Комментарий ревьюера:</b> Красный блок указывает на то, то в задании допущена ошибка, которая влияет на итоговые результаты, и без исправления которой работа не будет принята.
# </div>
#
#
#
# 📈 Не удаляй мои комментарии, так будет проще следить за динамикой.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента v1: </b> Отправляю на проверку общую тетрадь - чтобы декомпозиция была тут и все время перед глазами при выполнении основной части проекта. Также укрупненно разбил разделы проекта по ячекам, чтобы удобнее было оставлять комментарии. </div>

# %% [markdown]
#
# <div class="alert alert-block alert-warning">
# <b> ⚠️ Комментарий ревьюера:</b> Привет! Дождись, пожалуйста, вебинара. Все вопросы можешь задать на нём, или написать в чат, чтобы я могла на них ответить там
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента v2: </b> Переработал декомпозицию задачи после вебинара, добавил некоторые пункты + расширяю перечень возможных гипотез. Вопросы по пунктам декомпозиции задачи выделил жирным шрифтом. </div>

# %% [markdown]
# # Декомпозиция задачи
# - Название проекта, определение задачи и краткое описание процесса исследования `(Задачей данного исследования является определение новых актуальных сегментов, на которые можно разделить действующих клиентов банка. Дополнительная задача: проверить отток клиентов из сформированных сегментов для выявления причин, почему это происходит. Заказчиком данного исследования является отдел маркетинга банка. Цель исследования: определение и выделение новых актуальных сегментов клиентов банка таким образом, чтобы изменение банковских продуктов приводило к уменьшению отттока клиентов);`
# - Загрузка и обзор данных
# - Предобработка данных:
#     - Исследование пропущенных значений;
#     - Исследование соответствия типов данных и их изменение;
#     - Проверка корректности наименований колонок и их переименование (при необходимости);
#     - Исследование дубликатов и их удаление (при наличии и необходимости);
#     - Замена, заполнение пропущенных значений (при необходимости);
#     - Преобразование столбца с данными и поле клиентов в булев тип;
#     - Преобразование столбца с данными о городах в булев тип.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> ❌ Комментарий ревьюера:</b>  Не сформулированы цели и задачи
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента v3: </b> У нас же здесь вроде как план выполнения исследования? Предполагал, что цели и задачи будут подробнее расписаны как раз в самом проекте, в пункте "Определение задачи и краткое описание процесса исследования".
#
#
# В тетрадке проекта будет написано следующее:
#
# "Задачей данного исследования является определение новых актуальных сегментов, на которые можно разделить действующих клиентов банка. Дополнительная задача: проверить отток клиентов из сформированных сегментов для выявления причин, почему это происходит.
#
# Аналогичное исследование проводилось примерно 2 года назад, с тех пор структура клиентов поменялась - этим обоснована необходимость исследования.
#
# Заказчиком данного исследования является отдел маркетинга банка. Полученные результаты о сегментации клиентов банка предполагается использовать для изменения стратегии предложения клиентам банка его продуктов".</div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> ❌ Комментарий ревьюера 3:</b>  Да, мне важно посмотреть, что будет в начале тетрадки:) Нужно еще добавить цель, отвечающую на вопрос "зачем?"
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента v4: </b> Добавил в декомпозицию краткую версию целей и задач.</div>

# %% [markdown]
# - Исследовательский анализ данных **(?что сюда еще можно включить, а что откорректировать?)**:
#     - Общее кол-во уникальных клиентов;
#     - Распределение клиентов по городам + доли клиентов из каждого города в общем кол-ве клиентов;
#     - Присвоение определенной категории в зависимости от кредитного рейтинга. Построение гисторграммы и анализ получившегося результата;
#     - Средняя и медианная зарплата по городам. Анализ выбросов;
#     - Изучение баланса денежных средств на счетах клиентов. Анализ выбросов;
#     - Изучение возрастного диапазона клиентов банка. Разбитие клиентов по возрастным категориям. Анализ выбросов;
#     - Сводная таблица: возраст/пол - кредитный рейтинг **(?но тут возраст уже должен быть разбит по категориям?)**;
#     - Корреляция возраста и кредитного рейтинга **(думаю, что тут можно сделать корреляционную матрицу, если заранее поделить данные переменные на категории - надо только подумать, какие)**;
#     - ~Корреляция кол-ва продуктов в зависимости от города~;
#     - Определение, из каких категорий клиентов происходит самый большой отток: зависимость оттока от кредитного рейтинга, заработной платы, возраста, пола (вот тут может быть статистическая гипотеза о равенстве долей), города;
#     - Продукты, используемые клиентами из "зоны риска" (с низким скорингом);

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> ❌ Комментарий ревьюера:</b> Не исследованы аномалии. По корреляциям лучше построить одну матрицу
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента v3: </b> По поводу исследования аномалий: отдельно происходит изучение зарплаты по городам, баланса денежных средств на счете, возраста. И в каждом пункте добавлена фраза "Анализ выбросов", т.е. для каждой переменной буду строить boxplot и смотреть на выбросы, аномалии, дам комментарии в выводах.
#
#
# По поводу построения одной матрицы корреляции - ты имеешь ввиду корреляцию сразу всех величин со всеми величинами? Типа такого:
#
#     matrix_correlation = data.corr()
#
#
# И думаю, что по ней как раз будет видна сила связи одной переменной и другой (как положительная, так и отрицательная) и после этого этапа можно будет выбрать второй критерий, по которому будет проводиться сегментация клиентов.</div>

# %% [markdown]
# - Разделение пользователей на основе данных о количестве потребляемых продуктов **(?и на основе второго критерия, который пока что не очевиден?)** на категории ;
# - Исследование отличительных черт получившихся групп **(?что сюда может войти? Какие-нибудь аналогичные вещи из исследовательского анализа?)**;

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b> ⚠️ Комментарий ревьюера:</b> Лучше пройтись describe  и понять, какие отличительные черты:)
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента v3: </b> Знал об этом методе, но не думал, что можно применить его тут - в примерах видел его применение в самом начале исследования. Обязательно добавлю его в п. "Исследование отличительных черт получившихся групп"</div>

# %% [markdown]
#
# <div class="alert alert-block alert-success">
# <b>✔️ Комментарий ревьюера 4:</b> Да, всё верно, ок
# </div>

# %% [markdown]
# - Проверка статистических гипотез:
#     - Гипотеза №1: возраст клиентов, имеющих один продукт, равен возрасту клиентов, у которых два продукта банка;
#     - ~Гипотеза №2: вероятность ухода пользователя зависит от возраста **(?как переформулировать такую гипотезу, чтобы с чем-то ее сравнивать и подобрать для ее проверки подходящий статистический критерий?)**~
#     - Гипотеза №2: возраст клиентов группы А равен возрасту клиентов группы В (группы А и В будут ясны после сегментации клиентов по количеству продуктов и дополнительному признаку, декомпозиция будет дополнена);
#     - Гипотеза №3: доля клиентов с низким кредитным рейтингом (меньше 765) равна доле клиентов с высоким кредитным рейтингом (больше 950); **(но я еще точно не знаю, очевидно ли то, что эти доли равны или наоборот - не равны и есть ли вообще смысл проверять эту гипотезу. Также я пока не могу додуматься, чем результат проверки этой гипотезы может помочь заказчику исследования. Возможно ответы на эти вопросы и новые гипотезы появятся в процессе исследования)**

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> ❌ Комментарий ревьюера:</b> Во второй гипотезы лучше всего сравнить средние возраста двух групп, твоя формулировка некорректна
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента v3: </b> Имеешь ввиду двух получившихся групп?
#
# Гипотезу №2 переформулировал, по группам будет ясно после сегментации. Гипотезу №3 пока оставлю тут, как мысль для исследования - возможно она будет полезна.</div>

# %% [markdown]
#
# <div class="alert alert-block alert-success">
# <b>✔️ Комментарий ревьюера 3:</b> Можно проверить отточных и неотточных клиентов
# </div>

# %% [markdown]
# - Выводы по результатам исследования и рекомендации для заказчика.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b> ❌ Комментарий ревьюера:</b> Необходимо дополнить декомпозицию планом презентации
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента v3: </b> Добавил краткий план презентации.</div>

# %% [markdown]
# План презентации:
# - Название проекта, определение задачи и краткое описание процесса исследования
# - Обзор данных
# - Исследовательский анализ (краткое содержание)
# - По каким критериям проводилась сегментация пользователей, получившиеся группы
# - Статистические гипотезы: формулирование, доказательство, результаты расчетов
# - Выводы и рекомендации отделу маркетинга по результатам исследования

# %% [markdown]
#
# <div class="alert alert-block alert-warning">
# <b> ⚠️ Комментарий ревьюера 3:</b>Не забудь результаты проверки гипотез
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента v4: </b> Добавил краткий пункт по проверками статистических гипотез.</div>
